# %% [markdown]
# ## Built-in Tool - DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke("Today's news in India")

results
# Out:
# "Today ' s news : Get latest and Breaking News on Politics, Business, Lifestyle, Entertainment and Sports along with News updates from around the world. Also, find English News , live coverage on Bollywood, Cricket, Technology, Celebrities and more on indianexpress.com The Hindu Newspaper : Get latest News on Politics, Sports, Business, Arts, Entertainment and trending news Videos from The Hindu. India News Today : Read latest and breaking news headlines from India . Top India News , Current headlines, videos, photos and live india news updates at India Today 14 hours ago · Today ' s top India news headlines, news on Indian politics, elections, government, business, technology, and Bollywood. Read full articles, watch videos, browse thousands of titles and more on the ' India ' topic with Google News. Today ' s news : Get latest and Breaking News on Politics, Business, Lifestyle, Entertainment and Sports along with News updates from around the world. Also, find English News , live coverage on Bollywood, Cricket, Technology, Celebrities and more on indianexpress.com 3 hours ago · Times Now LIVE TV - Bihar Assembly Election Results 2025, Watch Live News on Times Now Live TV for all the latest and breaking news and updates from India , Politics, International News , Cities, Crime and all that matters to you. From the world of business, fashion and lifestyle, our reporters bring exclusive coverage from forums and events. The Hindu Newspaper: Get latest News on Politics, Sports, Business, Arts, Entertainment and trending news Videos from The Hindu 14 hours ago · Today ' s top India news headlines, news on Indian politics, elections, government, business, technology, and Bollywood. Read full articles, watch videos, browse thousands of titles and more on the ' India ' topic with Google News."

# %%
search_tool.name,search_tool.description,search_tool.args
# Out:
# ('duckduckgo_search',
#  'A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.',
#  {'query': {'description': 'search query to look up',
#    'title': 'Query',
#    'type': 'string'}})

# %% [markdown]
# ## Built-In Tool - Shell Tool

# %%
from langchain_community.tools import ShellTool

# %%
shell_tool = ShellTool()

results = shell_tool.invoke('whoami')
print(results)
# Out:
# Executing command:
#  whoami
# laptop-p8gt1qdm\ssahu
# C:\Users\ssahu\AppData\Roaming\Python\Python313\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %%
shell_tool.invoke('pwd')
# Out:
# Executing command:
#  pwd
# C:\Users\ssahu\AppData\Roaming\Python\Python313\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
# "'pwd' is not recognized as an internal or external command,\r\noperable program or batch file.\r\n"
