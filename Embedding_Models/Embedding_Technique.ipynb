# %% [markdown]
# ## Embedding Techniques

# %%
import os
from dotenv import load_dotenv
load_dotenv()  ##Load all the enviorment variables
# Out:
# True

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeeding_model = HuggingFaceEmbeddings(model='all-MiniLM-L6-v2')

# %%
text = 'This is a text document.'
embeeding_model.embed_query(text=text)
# Out:
# [-0.03905745595693588,
#  0.1383126825094223,
#  -0.017224565148353577,
#  0.02035033516585827,
#  0.0027080420404672623,
#  0.026372423395514488,
#  -0.0003251645539421588,
#  0.055297255516052246,
#  0.05006299167871475,
#  0.020780211314558983,
#  0.04126594588160515,
#  0.0974966436624527,
#  0.0036997178103774786,
#  -0.025052731856703758,
#  -0.07942777872085571,
#  0.014414388686418533,
#  -0.03149736672639847,
#  -0.046606648713350296,
#  0.014756147749722004,
#  0.04217344522476196,
#  0.06482817977666855,
#  0.1271832138299942,
#  0.034173738211393356,
#  -0.007149877026677132,
#  0.007870754227042198,
#  0.11034781485795975,
#  -0.10440374165773392,
#  0.016266297549009323,
#  0.03719066455960274,
#  -0.004992837551981211,
#  -0.00786519329994917,
#  0.06573965400457382,
#  0.13239729404449463,
#  0.042934123426675797,
#  0.026011116802692413,
#  0.015582365915179253,
#  0.010604909621179104,
#  0.02755359187722206,
#  0.01678021065890789,
#  0.0275128036737442,
# ...

# %%
len(embeeding_model.embed_query(text=text))
# Out:
# 384
